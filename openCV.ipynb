# %% [markdown]
# <a href="https://colab.research.google.com/github/rasaltejas/Learn_Artificial-intelligence/blob/main/openCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #How to install opencv on windows
#
# Download anaconda
#
# 1.conda create --name opencv-env
#
# 2.conda activate opencv-env
#
# 3.conda install -c
#
# 4.conda-forge opencv
#
# 5.import cv2 as cv

# %% [markdown]
# #import libraries

# %%
import os
'''What it does:Lets you interact with the operating system—like creating folders, reading files, or changing directories.
Why import it:To manage files and paths (e.g., saving images to a folder).
If not imported: You can’t use os.path, os.listdir, or any file system operations. You’ll get a NameError if you try to use them.'''


import cv2
'''What it does: A powerful library for image and video processing (reading, editing, detecting objects in images).
Why import it: To load and manipulate image data, apply filters, detect edges, etc.
If not imported: You can’t read images, apply transformations, or do any computer vision tasks. Trying to use cv2.imread() will throw a NameError.'''


import numpy as np
'''What it does: Handles arrays and matrices efficiently—perfect for storing and manipulating image data (images are just grids of numbers).
Why import it: Images are stored as NumPy arrays. You need this for math operations on pixels.
If not imported: You can’t create or process image arrays. Any operation like np.zeros() or array math will fail with a NameError.'''


import matplotlib.pyplot as plt
'''What it does: A plotting library used to display images or graphs.
Why import it: To visualize images or results (e.g., show an image after processing).
If not imported: You can’t display images using plt.imshow(). The function won’t exist, leading to a NameError.'''


from zipfile import ZipFile
'''What it does: Lets you read or extract files from a .zip archive.
Why import it: To unpack downloaded datasets (often in .zip format) for processing.
If not imported: You can’t open or extract .zip files. Trying to use ZipFile will raise a NameError.'''

from urllib.request import urlretrieve
'''What it does: Downloads files from a URL directly to your computer.
Why import it: To fetch images, datasets, or models from the internet (common in tutorials).
If not imported: You can’t download files automatically. You’d have to manually download them first.'''


from IPython.display import Image
'''What it does: Displays images directly in a notebook (like Google Colab) without saving them.
Why import it: To show images inline in the notebook output (cleaner than saving and loading).
If not imported: You can’t use Image() to display images in the notebook. You’d get a NameError.'''


# %matplotlib inline
''' tells the notebook to display plots directly below the code cell instead of opening a separate pop-up window.'''
# Out:
# ' tells the notebook to display plots directly below the code cell instead of opening a separate pop-up window.'

# %% [markdown]
# #Getting start with image

# %% [markdown]
# ##1. Environment Setup & Basics
#
# [ ] Using Jupyter Notebooks: Understanding why they are used for demonstrating intermediate results and providing documentation.
#
# [ ] Required Libraries: Importing essential libraries like OpenCV (cv2) and Matplotlib.
#
# [ ] Inline Display: Using %matplotlib inline to render images directly within a Jupyter Notebook

# %% [markdown]
# ##2. Image Representation & Data
#
# [ ] NumPy Arrays: Understanding that OpenCV reads images and stores them in memory as NumPy arrays.
#
# [ ] Data Types: Identifying that images are typically represented as unsigned 8-bit integers (uint8) with pixel intensities ranging from 0 to 255.
#
# [ ] Image Dimensions: Using methods like .shape to check an image's height, width, and number of channels.
#
# [ ] Grayscale vs. Color: Distinguishing between 2D arrays (grayscale) and 3D arrays (color)

# %% [markdown]
# ##3. Reading and Writing Images
#
# [ ] cv2.imread(): Learning to read images using relative or absolute paths.
#
# [ ] Read Flags: Using optional flags (like 0 for grayscale or 1 for color) when reading files.
#
# [ ] cv2.imwrite(): Saving processed images from your notebook back to disk.
#
# [ ] IPython Image Rendering: Using the IPython.display.Image function for faithful rendering in a browser

# %% [markdown]
# ##4. Displaying Images (Matplotlib vs. OpenCV)
#
# [ ] plt.imshow(): Using Matplotlib to plot mathematical representations of image data.
#
# [ ] Color Maps: Setting cmap='gray' in Matplotlib to correctly display grayscale images instead of the default color maps.
#
# [ ] cv2.imshow(): Using the OpenCV-specific display function in a development environment.
#
# [ ] Interactive Windows: Creating named windows with cv2.namedWindow().
#
# [ ] cv2.waitKey(): Managing how long a window stays open and handling keyboard inputs (e.g., using 'q' to quit or 0 to wait indefinitely)

# %% [markdown]
# ##5. Color Channels and Spaces
#
# [ ] BGR vs. RGB: Understanding that OpenCV defaults to BGR (Blue, Green, Red) order, while Matplotlib expects RGB
# .
#
# [ ] Channel Swapping: Learning the syntax to manually reverse channel order so images display correctly in Matplotlib
# .
#
# [ ] Splitting & Merging: Using cv2.split() to isolate individual R, G, and B channels and cv2.merge() to combine them back into a single image
# .
#
# [ ] cv2.cvtColor(): Converting images between different color spaces, such as BGR to RGB or BGR to HSV
# .
#
# [ ] HSV Color Space: Understanding the concepts of Hue (color), Saturation (intensity), and Value (brightness)
# .
#
# [ ] Channel Manipulation: Modifying a specific channel (like shifting the Hue) before merging and converting back for display.
